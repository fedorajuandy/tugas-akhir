# %% [markdown]
# # Benchmark

# %%
# GPU Quadro M4000 x 1

from ai_benchmark import AIBenchmark
results = AIBenchmark().run()
# Out:
# >>   AI-Benchmark-v.0.1.2
# >>   Let the AI Games begin..
#
# *  TF Version: 2.9.1
# *  Platform: Linux-5.4.0-122-generic-x86_64-with-glibc2.31
# *  CPU: N/A
# *  CPU RAM: 29 GB
# *  GPU/0: Quadro M4000
# *  GPU RAM: 7.3 GB
# *  CUDA Version: 11.2
# *  CUDA Build: V11.2.152
#
# The benchmark is running...
# The tests might take up to 20 minutes
# Please don't interrupt the script
#
# 1/19. MobileNet-V2
#
# 1.1 - inference | batch=50, size=224x224: 145 ± 2 ms
# 1.2 - training  | batch=50, size=224x224: 850 ± 1 ms
#
# 2/19. Inception-V3
#
# 2.1 - inference | batch=20, size=346x346: 201.9 ± 0.5 ms
# 2.2 - training  | batch=20, size=346x346: 758 ± 3 ms
#
# 3/19. Inception-V4
#
# 3.1 - inference | batch=10, size=346x346: 225.3 ± 0.9 ms
# 3.2 - training  | batch=10, size=346x346: 830 ± 1 ms
#
# 4/19. Inception-ResNet-V2
#
# 4.1 - inference | batch=10, size=346x346: 290 ± 1 ms
# 4.2 - training  | batch=8, size=346x346: 848 ± 1 ms
#
# 5/19. ResNet-V2-50
#
# ...
